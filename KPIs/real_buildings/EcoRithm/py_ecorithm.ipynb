# %%
import eco_connect
from eco_connect import FactsService

facts_service = FactsService()

# %%
s_date = '2018-1-1'
e_date = '2018-10-31'

# %%
df_data = facts_service.get_facts(
    building_id=60, 
    start_date='2017-8-1 8:00', 
    end_date='2018-9-30 8:00', 
    start_hour='8:00', 
    end_hour='9:00', 
    equipment_names=[], 
    equipment_types=[], 
    excluded_days=[], 
    excluded_dates=[], 
    point_classes=[], 
    eco_point_ids=[], 
    display_names=[], 
    native_names=[], 
    point_class_expression=[], 
    native_name_expression=[], 
    display_name_expression=[], 
    result_format='pandas'
    )

# %%
df_data.head(10)
# Out:
#           fact_time  fact_value  eco_point_id equipment_name  \
# 0  2018-01-01 08:00     188.000        237618      1st_Floor
# 1  2018-01-01 08:05     187.750        237618      1st_Floor
# 2  2018-01-01 08:10     187.750        237618      1st_Floor
# 3  2018-01-01 08:15     187.500        237618      1st_Floor
# 4  2018-01-01 08:20     187.500        237618      1st_Floor
# 5  2018-01-01 08:25     187.500        237618      1st_Floor
# 6  2018-01-01 08:30     187.500        237618      1st_Floor
# 7  2018-01-01 08:35     187.250        237618      1st_Floor
# 8  2018-01-01 08:40     187.250        237618      1st_Floor
# 9  2018-01-01 08:50     187.375        237618      1st_Floor
#
#                    point_class                          native_name  \
# 0  BoilerInletWaterTemperature  1ST-FL HOT WATER RETURN TEMPERATURE
# 1  BoilerInletWaterTemperature  1ST-FL HOT WATER RETURN TEMPERATURE
# 2  BoilerInletWaterTemperature  1ST-FL HOT WATER RETURN TEMPERATURE
# 3  BoilerInletWaterTemperature  1ST-FL HOT WATER RETURN TEMPERATURE
# 4  BoilerInletWaterTemperature  1ST-FL HOT WATER RETURN TEMPERATURE
# 5  BoilerInletWaterTemperature  1ST-FL HOT WATER RETURN TEMPERATURE
# 6  BoilerInletWaterTemperature  1ST-FL HOT WATER RETURN TEMPERATURE
# 7  BoilerInletWaterTemperature  1ST-FL HOT WATER RETURN TEMPERATURE
# 8  BoilerInletWaterTemperature  1ST-FL HOT WATER RETURN TEMPERATURE
# 9  BoilerInletWaterTemperature  1ST-FL HOT WATER RETURN TEMPERATURE
#
#          display_name equipment_type
# 0  HotWaterReturnTemp             HW
# 1  HotWaterReturnTemp             HW
# 2  HotWaterReturnTemp             HW
# 3  HotWaterReturnTemp             HW
# 4  HotWaterReturnTemp             HW
# 5  HotWaterReturnTemp             HW
# 6  HotWaterReturnTemp             HW
# 7  HotWaterReturnTemp             HW
# 8  HotWaterReturnTemp             HW
# 9  HotWaterReturnTemp             HW

# %%
df_data.tail(10)
# Out:
#                fact_time  fact_value  eco_point_id             equipment_name  \
# 540490  2018-05-22 08:15     25.1562        238437  SF09_2nd_to_8th_Perimeter
# 540491  2018-05-22 08:20      0.0000        238437  SF09_2nd_to_8th_Perimeter
# 540492  2018-05-22 08:25     50.3125        238437  SF09_2nd_to_8th_Perimeter
# 540493  2018-05-22 08:30     50.3125        238437  SF09_2nd_to_8th_Perimeter
# 540494  2018-05-22 08:35     50.3125        238437  SF09_2nd_to_8th_Perimeter
# 540495  2018-05-22 08:40     50.3125        238437  SF09_2nd_to_8th_Perimeter
# 540496  2018-05-22 08:45     50.3125        238437  SF09_2nd_to_8th_Perimeter
# 540497  2018-05-22 08:50     50.3125        238437  SF09_2nd_to_8th_Perimeter
# 540498  2018-05-22 08:55     50.3125        238437  SF09_2nd_to_8th_Perimeter
# 540499  2018-05-22 09:00     50.3125        238437  SF09_2nd_to_8th_Perimeter
#
#                   point_class       native_name            display_name  \
# 540490  SupplyFanUnitFeedback  F-9 VFD Feedback  SupplyFanSpeedFeedback
# 540491  SupplyFanUnitFeedback  F-9 VFD Feedback  SupplyFanSpeedFeedback
# 540492  SupplyFanUnitFeedback  F-9 VFD Feedback  SupplyFanSpeedFeedback
# 540493  SupplyFanUnitFeedback  F-9 VFD Feedback  SupplyFanSpeedFeedback
# 540494  SupplyFanUnitFeedback  F-9 VFD Feedback  SupplyFanSpeedFeedback
# 540495  SupplyFanUnitFeedback  F-9 VFD Feedback  SupplyFanSpeedFeedback
# 540496  SupplyFanUnitFeedback  F-9 VFD Feedback  SupplyFanSpeedFeedback
# 540497  SupplyFanUnitFeedback  F-9 VFD Feedback  SupplyFanSpeedFeedback
# 540498  SupplyFanUnitFeedback  F-9 VFD Feedback  SupplyFanSpeedFeedback
# 540499  SupplyFanUnitFeedback  F-9 VFD Feedback  SupplyFanSpeedFeedback
#
#        equipment_type
# 540490            AHU
# 540491            AHU
# 540492            AHU
# 540493            AHU
# 540494            AHU
# 540495            AHU
# 540496            AHU
# 540497            AHU
# 540498            AHU
# 540499            AHU

# %%
df_point_mapping = facts_service.get_point_mapping(building_id = 60, result_format = 'pandas')
df_point_mapping.to_csv('point_mapping.csv', index = False)

# %%
df_equipments = facts_service.get_equipment(building_id = 60, result_format = 'pandas')
df_equipments.to_csv('equipments.csv', index = False)

# %%
df_native_names = facts_service.get_native_names(building_id = 60, result_format = 'pandas')
df_native_names.to_csv('native_names.csv', index = False)

# %%
df_native_names.head()
cond = df_native_names['native_name'].str.contains('Occupancy')
v_native_names_occupancy = list(df_native_names[cond].native_name.unique())

# %%
df_occ_data = facts_service.get_facts(
    building_id=60, 
    start_date=s_date + ' 0:00', 
    end_date=e_date + ' 0:00', 
    equipment_names=['VAV_05_01'], 
    equipment_types=[], 
    point_classes=[], 
    eco_point_ids=[], 
    display_names=[], 
    native_names=v_native_names_occupancy, 
    result_format='pandas'
    )

# %%
df_occ_data.to_csv(s_date + '~' + e_date + '_occ_data.csv', index = False)
